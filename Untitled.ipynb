# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Loan_default_cleaned_encoded.csv")
df.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio  Education  EmploymentType  MaritalStatus  \
# 0         15.23        36      0.44          0               0              0
# 1          4.81        60      0.68          2               0              1
# 2         21.17        24      0.31          2               3              0
# 3          7.07        24      0.23          1               0              1
# 4          6.51        48      0.73          0               3              0
#
#    HasMortgage  HasDependents  LoanPurpose  HasCoSigner  Default
# 0            1              1            4            1        0
# 1            0              0            4            1        0
# 2            1              1            0            0        1
# 3            0              0            1            0        0
# 4            0              1            0            0        0

# %%
df.shape
# Out:
# (255347, 17)

# %%
df["Default"].value_counts()
# Out:
# Default
# 0    225694
# 1     29653
# Name: count, dtype: int64

# %%
X = df.drop(columns=["Default"])
y = df.iloc[: , -1]

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.25 , random_state=42)

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    roc_auc_score
)

# Create model
brf = BalancedRandomForestClassifier(
    random_state=42
)

# Parameter grid
param_grid = {
    'n_estimators': [100 ,200],
    'max_depth': [ 10, 20],
    'min_samples_split': [ 5, 10],
    'min_samples_leaf': [2, 4],
    'sampling_strategy': ['auto', 0.5]
}

# Grid Search
grid_search = GridSearchCV(
    estimator=brf,
    param_grid=param_grid,
    cv=4,
    scoring='f1',
    n_jobs=-1,
    verbose=2
)

# Train
grid_search.fit(X_train, y_train)

# Best parameters
print("Best Parameters:")
print(grid_search.best_params_)

# Best CV F1
print("\nBest CV F1:")
print(grid_search.best_score_)

# Best model
best_brf = grid_search.best_estimator_

# Prediction
y_pred = best_brf.predict(X_test)

# Accuracy
print("\nTest Accuracy:")
print(accuracy_score(y_test, y_pred))

# ROC-AUC
y_prob = best_brf.predict_proba(X_test)[:, 1]

print("\nROC-AUC:")
print(roc_auc_score(y_test, y_prob))

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Fitting 4 folds for each of 32 candidates, totalling 128 fits
# Best Parameters:
# {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200, 'sampling_strategy': 0.5}
#
# Best CV F1:
# 0.3570262809124841
#
# Test Accuracy:
# 0.8160471200087723
#
# ROC-AUC:
# 0.7463929192076888
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.89     56410
#            1       0.30      0.44      0.36      7427
#
#     accuracy                           0.82     63837
#    macro avg       0.61      0.65      0.63     63837
# weighted avg       0.85      0.82      0.83     63837
#
#
# Confusion Matrix:
# [[48826  7584]
#  [ 4159  3268]]

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

y_prob = best_brf.predict_proba(X_test)[:, 1]

thresholds = np.arange(0.10, 0.91, 0.05)

for threshold in thresholds:

    y_pred = (y_prob >= threshold).astype(int)

    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print(
        f"Threshold: {threshold:.2f} | "
        f"Precision: {precision:.3f} | "
        f"Recall: {recall:.3f} | "
        f"F1: {f1:.3f}"
    )
# Out:
# Threshold: 0.10 | Precision: 0.124 | Recall: 0.989 | F1: 0.220
# Threshold: 0.15 | Precision: 0.136 | Recall: 0.957 | F1: 0.237
# Threshold: 0.20 | Precision: 0.151 | Recall: 0.915 | F1: 0.260
# Threshold: 0.25 | Precision: 0.168 | Recall: 0.850 | F1: 0.281
# Threshold: 0.30 | Precision: 0.190 | Recall: 0.782 | F1: 0.306
# Threshold: 0.35 | Precision: 0.214 | Recall: 0.702 | F1: 0.328
# Threshold: 0.40 | Precision: 0.241 | Recall: 0.618 | F1: 0.347
# Threshold: 0.45 | Precision: 0.270 | Recall: 0.529 | F1: 0.358
# Threshold: 0.50 | Precision: 0.301 | Recall: 0.440 | F1: 0.358
# Threshold: 0.55 | Precision: 0.338 | Recall: 0.355 | F1: 0.346
# Threshold: 0.60 | Precision: 0.384 | Recall: 0.271 | F1: 0.317
# Threshold: 0.65 | Precision: 0.434 | Recall: 0.193 | F1: 0.267
# Threshold: 0.70 | Precision: 0.506 | Recall: 0.128 | F1: 0.205
# Threshold: 0.75 | Precision: 0.559 | Recall: 0.075 | F1: 0.132
# Threshold: 0.80 | Precision: 0.648 | Recall: 0.039 | F1: 0.074
# Threshold: 0.85 | Precision: 0.743 | Recall: 0.015 | F1: 0.029
# Threshold: 0.90 | Precision: 0.786 | Recall: 0.003 | F1: 0.006

# %%
from imblearn.ensemble import BalancedRandomForestClassifier

model = BalancedRandomForestClassifier(
    n_estimators=200,
    max_depth = 20,
    min_samples_split=10,
    min_samples_leaf=2,
    sampling_strategy= 0.5
)

model.fit(X_train , y_train)
# Out:
# BalancedRandomForestClassifier(max_depth=20, min_samples_leaf=2,
#                                min_samples_split=10, n_estimators=200,
#                                sampling_strategy=0.5)

# %%
y_pred = model.predict(X_test)

# %%
# print(classification_report(y_test, y_pred))

# %%
import joblib

joblib.dump(model, "balanced_random_forest.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!
